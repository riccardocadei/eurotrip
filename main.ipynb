# %%
from src.formulation import optimal_schedule
from src.visualize import visualize_schedule
from src.utils import load_route, load_skills, load_schedule

# %%
# load data
route = load_route()
skills = load_skills()

# %%
skills
# Out:
#      Runner  max_drive  drive_night  min_long_rest  max_run  min_run  max_D+  \
# 0   Florian        200            1              0       65       55    1000
# 1    Esther          0            0              4       50       40     500
# 2    Monika          0            0              4       50       40     500
# 3      Paul          0            0              3       50       40     500
# 4      Alex        200            1              3       50       40     500
# 5  Riccardo          0            1              0       60       45     500
# 6     Anton          0            0              3       55       45     700
# 7  Benjamin        150            1              0       60       45    2000
#
#    pace_HM  endurance    K+    K-  p_night
# 0      210     0.0020  0.30 -0.10        0
# 1      250     0.0040  0.55 -0.05        2
# 2      260     0.0040  0.55 -0.05        2
# 3      210     0.0030  0.55 -0.05        2
# 4      220     0.0030  0.50 -0.08        2
# 5      220     0.0020  0.50 -0.12        0
# 6      220     0.0030  0.40 -0.10        0
# 7      225     0.0035  0.30 -0.15        0

# %%
schedule, summary = optimal_schedule(route, skills, 
                                    toll=1e-4,
                                    time_limit=60, 
                                    save=True, 
                                    quadratic=True,
                                    max_drive_change=5)
summary
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2668062
# Academic license - for non-commercial use only - expires 2026-05-19
# Set parameter MIPGap to value 0.0001
# Set parameter TimeLimit to value 60
# Gurobi Optimizer version 12.0.2 build v12.0.2rc0 (mac64[rosetta2] - Darwin 23.6.0 23G93)
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  60
#
# Optimize a model with 2751 rows, 1017 columns and 8520 nonzeros
# Model fingerprint: 0x0cd1a586
# Model has 8 quadratic constraints
# Variable types: 40 continuous, 977 integer (977 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+02]
#   QMatrix range    [4e-01, 1e+00]
#   QLMatrix range   [5e-02, 2e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+03]
# Presolve removed 1854 rows and 395 columns
# Presolve time: 0.01s
# Presolved: 897 rows, 622 columns, 3864 nonzeros
# Presolved model has 8 quadratic objective terms
# Variable types: 8 continuous, 614 integer (594 binary)
#
# Root relaxation: objective 9.391638e+04, 6043 iterations, 0.12 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 93916.3772    0  263          - 93916.3772      -     -    0s
#      0     0 93922.6539    0  279          - 93922.6539      -     -    0s
#      0     0 93922.8434    0  313          - 93922.8434      -     -    0s
#      0     0 93922.8434    0  315          - 93922.8434      -     -    0s
#      0     0 93929.9487    0  301          - 93929.9487      -     -    0s
#      0     0 93930.1538    0  286          - 93930.1538      -     -    0s
#      0     0 93930.1544    0  287          - 93930.1544      -     -    0s
#      0     0 93934.5097    0  330          - 93934.5097      -     -    0s
#      0     0 93934.5533    0  331          - 93934.5533      -     -    0s
#      0     0 93935.9037    0  315          - 93935.9037      -     -    0s
#      0     0 93936.0064    0  325          - 93936.0064      -     -    0s
#      0     0 93936.0064    0  330          - 93936.0064      -     -    0s
#      0     0 93936.6447    0  342          - 93936.6447      -     -    0s
#      0     0 93936.7529    0  349          - 93936.7529      -     -    0s
#      0     0 93937.2607    0  331          - 93937.2607      -     -    0s
#      0     0 93937.4090    0  347          - 93937.4090      -     -    0s
#      0     0 93937.4090    0  348          - 93937.4090      -     -    0s
#      0     0 93939.0988    0  329          - 93939.0988      -     -    0s
#      0     0 93939.3390    0  331          - 93939.3390      -     -    0s
#      0     0 93939.3704    0  340          - 93939.3704      -     -    0s
#      0     2 93957.6289    0  338 94233.7784 93957.6289  0.29%     -    1s
# H   51    55                    94221.747425 93961.2569  0.28%   380    2s
# H   83    90                    94217.047425 93961.2569  0.27%   425    2s
# H  118   128                    94216.522425 93961.2569  0.27%   388    2s
# H  125   128                    94149.068925 93961.2569  0.20%   402    2s
# H  126   128                    94129.883425 93961.2569  0.18%   404    2s
# H  165   199                    94123.536425 93961.2569  0.17%   363    2s
# H  294   298                    94114.064925 93961.2569  0.16%   318    2s
# H  355   334                    94107.445725 93961.2569  0.16%   303    3s
# H  400   356                    94097.352225 93961.2569  0.14%   296    3s
# H  528   461                    94093.926725 93961.2569  0.14%   281    3s
# H  934   727                    94090.331600 93962.6650  0.14%   260    4s
#   1194   911 94010.1058   13  228 94090.3316 93966.2545  0.13%   252    5s
#   2440  1504 94080.8801   37  161 94090.3316 93970.7574  0.13%   265   10s
# H 2563  1496                    94061.964525 93970.7574  0.10%   265   10s
# H 2631  1484                    94049.579725 93971.1119  0.08%   265   10s
# H 2657  1415                    94046.784225 93971.1119  0.08%   264   10s
#   4663  1751 94041.3954   29  143 94046.7842 93978.3177  0.07%   253   15s
# H 5399  1451                    94027.606300 93979.2890  0.05%   253   16s
#   7235  2082 93999.1751   22  272 94027.6063 93983.0100  0.05%   249   20s
# * 7787  2058              46    94026.267925 93983.7218  0.05%   247   20s
#  10070  2619 94025.6214   25  189 94026.2679 93986.4735  0.04%   243   25s
#  12314  3071     cutoff   28      94026.2679 93988.6390  0.04%   239   30s
#  15004  3524 93999.5840   29  288 94026.2679 93990.5848  0.04%   235   35s
#  18136  3961 94005.3708   23  245 94026.2679 93993.4591  0.03%   233   40s
#  21339  4269     cutoff   33      94026.2679 93995.7048  0.03%   230   45s
# *22465  4319              49    94026.194925 93996.2003  0.03%   229   47s
#  24588  4440 94014.6983   24  305 94026.1949 93997.5929  0.03%   227   51s
#  27322  4495     cutoff   29      94026.1949 93999.0972  0.03%   225   55s
#
# Cutting planes:
#   Gomory: 4
#   Cover: 61
#   Implied bound: 2
#   MIR: 39
#   StrongCG: 2
#   Flow cover: 5
#   GUB cover: 14
#   Zero half: 118
#
# Explored 28964 nodes (6531532 simplex iterations) in 60.01 seconds (54.90 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 94026.2 94026.3 94027.6 ... 94107.4
#
# Time limit reached
# Best objective 9.402619492500e+04, best bound 9.399999543050e+04, gap 0.0279%
# Time limit reached. Using best feasible solution found.
# Expected Time: 26h07m06s
#           Legs  Distance   D+   D-  Driving  Driving shifts Base pace
# Runner
# Florian     11      62.7  815  617     79.0               2      3:47
# Esther       8      40.0  290  400      0.0               0      4:29
# Monika       8      40.0  180  377      0.0               0      4:39
# Paul         9      50.0  320  432      0.0               0      3:48
# Alex         7      40.0   95  325    161.0               2      3:52
# Riccardo    11      59.3  400  722      0.0               0      3:56
# Anton        9      45.3  645  440      0.0               0      3:56
# Benjamin     9      45.7  755  425    143.0               1      4:04

# %%
# visualize schedule
visualize_schedule(schedule, skills)

# %%
# Design choices to discuss: 
# force route assignment
# update skills
# requested rest after driving before running

# Bonus:
# get ETA end of each segment
# develop 'online' version
